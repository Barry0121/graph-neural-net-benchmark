# %%
import networkx as nx 
import numpy as np

# %% [markdown]
# # Q5

# %%
# generate network with <k> = 0.5
k_05 = nx.gnp_random_graph(n=300, p=1/598)
nx.draw(k_05, node_size=4)

# %%
# generate network with <k> = 2
k_2 = nx.gnp_random_graph(n=300, p=2/299)
nx.draw(k_2, node_size=4)

# %%
# generate network with <k> = 10
k_10 = nx.gnp_random_graph(n=300, p=10/299)
nx.draw(k_10, node_size=4, width=0.1)

# %% [markdown]
# # Q6
